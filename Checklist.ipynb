# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
#三种形式的贝叶斯概率

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [raw]
#   PRML说的Bayesian主要还是指Empirical Bayesian。Optimization/approximationLinear/Quadratic/Convex optimization：求线性/二次/凸函数的最值Lagrange multiplier：带（等式或不等式）约束的最值Gradient decent：求最值Newton iteration：解方程Laplace approximation：近似Expectation Maximation (EM)：求最值/近似，latent variable model中几乎无处不在Variational inference：求泛函最值Expectation Propagation (EP)：求泛函最值MCMC/Gibbs sampling：采样

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
